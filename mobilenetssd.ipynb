# %% [markdown]
# <a href="https://colab.research.google.com/github/Keni20/Music-Genre-Classification-with-Python/blob/master/mobilenetssd.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git clone https://github.com/qfgaohao/pytorch-ssd.git
# Out:
# Cloning into 'pytorch-ssd'...
# remote: Enumerating objects: 812, done.
# remote: Total 812 (delta 0), reused 0 (delta 0), pack-reused 812
# Receiving objects: 100% (812/812), 1.05 MiB | 35.84 MiB/s, done.
# Resolving deltas: 100% (544/544), done.

# %%
# !wget -P models https://storage.googleapis.com/models-hao/mobilenet-v1-ssd-mp-0_675.pth
# !mv /content/models/mobilenet-v1-ssd-mp-0_675.pth /content/pytorch-ssd/models
# Out:
# --2021-04-01 14:14:57--  https://storage.googleapis.com/models-hao/mobilenet-v1-ssd-mp-0_675.pth
# Resolving storage.googleapis.com (storage.googleapis.com)... 173.194.207.128, 173.194.208.128, 173.194.205.128, ...
# Connecting to storage.googleapis.com (storage.googleapis.com)|173.194.207.128|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 37995286 (36M) [application/octet-stream]
# Saving to: ‘models/mobilenet-v1-ssd-mp-0_675.pth.1’
#
# mobilenet-v1-ssd-mp 100%[===================>]  36.23M  83.4MB/s    in 0.4s
#
# 2021-04-01 14:14:57 (83.4 MB/s) - ‘models/mobilenet-v1-ssd-mp-0_675.pth.1’ saved [37995286/37995286]

# %%
# !wget -P models https://storage.googleapis.com/models-hao/voc-model-labels.txt
# !mv /content/models/voc-model-labels.txt /content/pytorch-ssd/models
# Out:
# --2021-04-01 14:15:01--  https://storage.googleapis.com/models-hao/voc-model-labels.txt
# Resolving storage.googleapis.com (storage.googleapis.com)... 172.217.164.176, 172.253.115.128, 172.217.2.112, ...
# Connecting to storage.googleapis.com (storage.googleapis.com)|172.217.164.176|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 145 [text/plain]
# Saving to: ‘models/voc-model-labels.txt.1’
#
# voc-model-labels.tx 100%[===================>]     145  --.-KB/s    in 0s
#
# 2021-04-01 14:15:01 (36.0 MB/s) - ‘models/voc-model-labels.txt.1’ saved [145/145]

# %%
# !cd /content/pytorch-ssd && python run_ssd_live_demo.py mb1-ssd models/mobilenet-v1-ssd-mp-0_675.pth models/voc-model-labels.txt /content/drive/MyDrive/testvideo2.mp4
# Out:
# Inference time:  0.009415864944458008
# Time: 0.02s, Detect Objects: 0.
# Inference time:  0.0049173831939697266
# Time: 0.01s, Detect Objects: 0.
# Inference time:  0.004355430603027344
# Time: 0.01s, Detect Objects: 0.
# Inference time:  0.004652261734008789
# Time: 0.01s, Detect Objects: 0.
# Inference time:  0.004357337951660156
# Time: 0.01s, Detect Objects: 0.
# Inference time:  0.004573822021484375
# Time: 0.02s, Detect Objects: 2.
# Inference time:  0.0048065185546875
# Time: 0.01s, Detect Objects: 1.
# Inference time:  0.00443267822265625
# Time: 0.01s, Detect Objects: 1.
# Inference time:  0.004381656646728516
# Time: 0.01s, Detect Objects: 1.
# Inference time:  0.004986286163330078
# Time: 0.01s, Detect Objects: 1.
# Inference time:  0.005291461944580078
# Time: 0.01s, Detect Objects: 1.
# Inference time:  0.004324913024902344
# Time: 0.01s, Detect Objects: 1.
# Inference time:  0.005332469940185547
# Time: 0.01s, Detect Objects: 0.
# Inference time:  0.004544258117675781
# ...

# %%
# !wget -P models https://storage.googleapis.com/models-hao/mobilenet_v1_ssd_caffe2/mobilenet-v1-ssd_init_net.pb
# !mv /content/models/mobilenet-v1-ssd_init_net.pb /content/pytorch-ssd/models
# !wget -P models https://storage.googleapis.com/models-hao/mobilenet_v1_ssd_caffe2/mobilenet-v1-ssd_predict_net.pb
# !mv /content/models/mobilenet-v1-ssd_predict_net.pb /content/pytorch-ssd/models
# Out:
# --2021-04-01 14:24:15--  https://storage.googleapis.com/models-hao/mobilenet_v1_ssd_caffe2/mobilenet-v1-ssd_init_net.pb
# Resolving storage.googleapis.com (storage.googleapis.com)... 172.217.9.208, 172.217.12.240, 172.217.15.112, ...
# Connecting to storage.googleapis.com (storage.googleapis.com)|172.217.9.208|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 47555863 (45M) [application/octet-stream]
# Saving to: ‘models/mobilenet-v1-ssd_init_net.pb’
#
# mobilenet-v1-ssd_in 100%[===================>]  45.35M  64.2MB/s    in 0.7s
#
# 2021-04-01 14:24:16 (64.2 MB/s) - ‘models/mobilenet-v1-ssd_init_net.pb’ saved [47555863/47555863]
#
# --2021-04-01 14:24:16--  https://storage.googleapis.com/models-hao/mobilenet_v1_ssd_caffe2/mobilenet-v1-ssd_predict_net.pb
# Resolving storage.googleapis.com (storage.googleapis.com)... 142.250.73.240, 172.217.7.240, 172.253.62.128, ...
# ...

# %%
#!cd pytorch-ssd && python run_ssd_live_caffe2.py models/mobilenet-v1-ssd_init_net.pb models/mobilenet-v1-ssd_predict_net.pb models/voc-model-labels.txt /content/drive/MyDrive/testvideo2.mp4
# Out:
# priors.shape (3000, 4)
# [W init.h:137] Caffe2 GlobalInit should be run before any other API calls.
# [W init.h:137] Caffe2 GlobalInit should be run before any other API calls.
# [W predictor_config.cc:90] Caffe2 is compiled without optimization passes.
# Inference Time: 0.17s.
# NMS Time: 0.00s, Detect Objects: 0.
# Inference Time: 0.13s.
# NMS Time: 0.00s, Detect Objects: 0.
# Inference Time: 0.13s.
# NMS Time: 0.00s, Detect Objects: 0.
# Inference Time: 0.13s.
# NMS Time: 0.00s, Detect Objects: 0.
# Inference Time: 0.13s.
# NMS Time: 0.00s, Detect Objects: 0.
# Inference Time: 0.13s.
# NMS Time: 0.00s, Detect Objects: 0.
# Inference Time: 0.13s.
# NMS Time: 0.00s, Detect Objects: 1.
# Inference Time: 0.13s.
# NMS Time: 0.00s, Detect Objects: 1.
# Inference Time: 0.13s.
# NMS Time: 0.00s, Detect Objects: 1.
# Inference Time: 0.12s.
# NMS Time: 0.00s, Detect Objects: 1.
# Inference Time: 0.13s.
# NMS Time: 0.00s, Detect Objects: 1.
# Inference Time: 0.13s.
# ...

# %%
# !wget -P models https://s3.amazonaws.com/amdegroot-models/vgg16_reducedfc.pth
# !mv /content/models/vgg16_reducedfc.pth /content/pytorch-ssd/models
# Out:
# --2021-04-01 14:24:27--  https://s3.amazonaws.com/amdegroot-models/vgg16_reducedfc.pth
# Resolving s3.amazonaws.com (s3.amazonaws.com)... 52.217.193.120
# Connecting to s3.amazonaws.com (s3.amazonaws.com)|52.217.193.120|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 81938914 (78M) [binary/octet-stream]
# Saving to: ‘models/vgg16_reducedfc.pth’
#
# vgg16_reducedfc.pth 100%[===================>]  78.14M  83.4MB/s    in 0.9s
#
# 2021-04-01 14:24:28 (83.4 MB/s) - ‘models/vgg16_reducedfc.pth’ saved [81938914/81938914]

# %%
#!cd pytorch-ssd && python train_ssd.py --datasets ~/data/VOC0712/VOC2007/ ~/data/VOC0712/VOC2012/ --validation_dataset ~/data/VOC0712/test/VOC2007/ --net vgg16-ssd --base_net models/vgg16_reducedfc.pth  --batch_size 24 --num_epochs 200 --scheduler "multi-step" --milestones "120,160"
# Out:
# 2021-04-01 09:05:17,959 - root - INFO - Use Cuda.
# 2021-04-01 09:05:17,959 - root - INFO - Namespace(balance_data=False, base_net='models/vgg16_reducedfc.pth', base_net_lr=None, batch_size=24, checkpoint_folder='models/', dataset_type='voc', datasets=['/root/data/VOC0712/VOC2007/', '/root/data/VOC0712/VOC2012/'], debug_steps=100, extra_layers_lr=None, freeze_base_net=False, freeze_net=False, gamma=0.1, lr=0.001, mb2_width_mult=1.0, milestones='120,160', momentum=0.9, net='vgg16-ssd', num_epochs=200, num_workers=4, pretrained_ssd=None, resume=None, scheduler='multi-step', t_max=120, use_cuda=True, validation_dataset='/root/data/VOC0712/test/VOC2007/', validation_epochs=5, weight_decay=0.0005)
# 2021-04-01 09:05:17,961 - root - INFO - Prepare training datasets.
# Traceback (most recent call last):
#   File "train_ssd.py", line 211, in <module>
#     target_transform=target_transform)
#   File "/content/pytorch-ssd/vision/datasets/voc_dataset.py", line 24, in __init__
# ...

# %%
#!wget http://host.robots.ox.ac.uk:8080/pascal/VOC/voc2012/VOCtrainval_11-May-2012.tar
# Out:
# --2021-04-01 09:25:04--  http://host.robots.ox.ac.uk:8080/pascal/VOC/voc2012/VOCtrainval_11-May-2012.tar
# Resolving host.robots.ox.ac.uk (host.robots.ox.ac.uk)... 129.67.94.152
# Connecting to host.robots.ox.ac.uk (host.robots.ox.ac.uk)|129.67.94.152|:8080... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1999639040 (1.9G) [application/x-tar]
# Saving to: ‘VOCtrainval_11-May-2012.tar’
#
# VOCtrainval_11-May- 100%[===================>]   1.86G  5.05MB/s    in 6m 31s
#
# 2021-04-01 09:31:36 (4.87 MB/s) - ‘VOCtrainval_11-May-2012.tar’ saved [1999639040/1999639040]

# %%
#!tar -xvf '/content/VOCtrainval_11-May-2012.tar' -C '/content/drive/MyDrive/data'
# Out:
# Streaming output truncated to the last 5000 lines.
# VOCdevkit/VOC2012/SegmentationClass/2008_001874.png
# VOCdevkit/VOC2012/SegmentationClass/2008_001876.png
# VOCdevkit/VOC2012/SegmentationClass/2008_001882.png
# VOCdevkit/VOC2012/SegmentationClass/2008_001885.png
# VOCdevkit/VOC2012/SegmentationClass/2008_001895.png
# VOCdevkit/VOC2012/SegmentationClass/2008_001896.png
# VOCdevkit/VOC2012/SegmentationClass/2008_001926.png
# VOCdevkit/VOC2012/SegmentationClass/2008_001966.png
# VOCdevkit/VOC2012/SegmentationClass/2008_001971.png
# VOCdevkit/VOC2012/SegmentationClass/2008_001992.png
# VOCdevkit/VOC2012/SegmentationClass/2008_001997.png
# VOCdevkit/VOC2012/SegmentationClass/2008_002032.png
# VOCdevkit/VOC2012/SegmentationClass/2008_002043.png
# VOCdevkit/VOC2012/SegmentationClass/2008_002064.png
# VOCdevkit/VOC2012/SegmentationClass/2008_002066.png
# VOCdevkit/VOC2012/SegmentationClass/2008_002067.png
# VOCdevkit/VOC2012/SegmentationClass/2008_002073.png
# ...

# %%
# !wget -P models https://s3.amazonaws.com/amdegroot-models/vgg16_reducedfc.pth

# !mv /content/models/vgg16_reducedfc.pth /content/pytorch-ssd/models
# Out:
# --2021-04-01 14:24:32--  https://s3.amazonaws.com/amdegroot-models/vgg16_reducedfc.pth
# Resolving s3.amazonaws.com (s3.amazonaws.com)... 52.217.77.62
# Connecting to s3.amazonaws.com (s3.amazonaws.com)|52.217.77.62|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 81938914 (78M) [binary/octet-stream]
# Saving to: ‘models/vgg16_reducedfc.pth’
#
# vgg16_reducedfc.pth 100%[===================>]  78.14M  87.8MB/s    in 0.9s
#
# 2021-04-01 14:24:33 (87.8 MB/s) - ‘models/vgg16_reducedfc.pth’ saved [81938914/81938914]

# %%
# !wget -P models https://storage.googleapis.com/models-hao/mb2-imagenet-71_8.pth

# !mv /content/models/mb2-imagenet-71_8.pth /content/pytorch-ssd/models
# Out:
# --2021-04-01 14:24:35--  https://storage.googleapis.com/models-hao/mb2-imagenet-71_8.pth
# Resolving storage.googleapis.com (storage.googleapis.com)... 172.217.9.208, 172.217.12.240, 172.217.7.240, ...
# Connecting to storage.googleapis.com (storage.googleapis.com)|172.217.9.208|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 9067303 (8.6M) [application/octet-stream]
# Saving to: ‘models/mb2-imagenet-71_8.pth’
#
# mb2-imagenet-71_8.p 100%[===================>]   8.65M  --.-KB/s    in 0.07s
#
# 2021-04-01 14:24:35 (119 MB/s) - ‘models/mb2-imagenet-71_8.pth’ saved [9067303/9067303]

# %%
#!wget http://host.robots.ox.ac.uk:8080/pascal/VOC/voc2007/VOCtrainval_06-Nov-2007.tar
# Out:
# --2021-04-01 12:41:33--  http://host.robots.ox.ac.uk:8080/pascal/VOC/voc2007/VOCtrainval_06-Nov-2007.tar
# Resolving host.robots.ox.ac.uk (host.robots.ox.ac.uk)... 129.67.94.152
# Connecting to host.robots.ox.ac.uk (host.robots.ox.ac.uk)|129.67.94.152|:8080... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 460032000 (439M) [application/x-tar]
# Saving to: ‘VOCtrainval_06-Nov-2007.tar’
#
# VOCtrainval_06-Nov- 100%[===================>] 438.72M  5.29MB/s    in 87s
#
# 2021-04-01 12:43:02 (5.05 MB/s) - ‘VOCtrainval_06-Nov-2007.tar’ saved [460032000/460032000]

# %%
#!tar xvf /content/VOCtrainval_06-Nov-2007.tar -C /content/drive/MyDrive/data
# Out:
# Streaming output truncated to the last 5000 lines.
# VOCdevkit/VOC2007/JPEGImages/001732.jpg
# VOCdevkit/VOC2007/JPEGImages/001733.jpg
# VOCdevkit/VOC2007/JPEGImages/001734.jpg
# VOCdevkit/VOC2007/JPEGImages/001738.jpg
# VOCdevkit/VOC2007/JPEGImages/001739.jpg
# VOCdevkit/VOC2007/JPEGImages/001741.jpg
# VOCdevkit/VOC2007/JPEGImages/001746.jpg
# VOCdevkit/VOC2007/JPEGImages/001747.jpg
# VOCdevkit/VOC2007/JPEGImages/001749.jpg
# VOCdevkit/VOC2007/JPEGImages/001750.jpg
# VOCdevkit/VOC2007/JPEGImages/001752.jpg
# VOCdevkit/VOC2007/JPEGImages/001754.jpg
# VOCdevkit/VOC2007/JPEGImages/001755.jpg
# VOCdevkit/VOC2007/JPEGImages/001756.jpg
# VOCdevkit/VOC2007/JPEGImages/001758.jpg
# VOCdevkit/VOC2007/JPEGImages/001759.jpg
# VOCdevkit/VOC2007/JPEGImages/001761.jpg
# VOCdevkit/VOC2007/JPEGImages/001765.jpg
# VOCdevkit/VOC2007/JPEGImages/001766.jpg
# VOCdevkit/VOC2007/JPEGImages/001768.jpg
# VOCdevkit/VOC2007/JPEGImages/001771.jpg
# VOCdevkit/VOC2007/JPEGImages/001772.jpg
# ...

# %%
#python train_ssd.py --dataset_type voc  --datasets ~/data/VOC0712/VOC2007 ~/data/VOC0712/VOC2012 --validation_dataset ~/data/VOC0712/test/VOC2007/ --net mb2-ssd-lite --base_net models/mb2-imagenet-71_8.pth  --scheduler cosine --lr 0.01 --t_max 200 --validation_epochs 5 --num_epochs 200

# %%
#!wget http://host.robots.ox.ac.uk:8080/pascal/VOC/voc2012/VOCtrainval_11-May-2012.tar
# Out:
# --2021-04-01 12:55:27--  http://host.robots.ox.ac.uk:8080/pascal/VOC/voc2012/VOCtrainval_11-May-2012.tar
# Resolving host.robots.ox.ac.uk (host.robots.ox.ac.uk)... 129.67.94.152
# Connecting to host.robots.ox.ac.uk (host.robots.ox.ac.uk)|129.67.94.152|:8080... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1999639040 (1.9G) [application/x-tar]
# Saving to: ‘VOCtrainval_11-May-2012.tar’
#
# VOCtrainval_11-May- 100%[===================>]   1.86G  5.20MB/s    in 6m 12s
#
# 2021-04-01 13:01:53 (5.13 MB/s) - ‘VOCtrainval_11-May-2012.tar’ saved [1999639040/1999639040]

# %%
#!tar -xvf /content/VOCtrainval_11-May-2012.tar -C /content/drive/MyDrive/data
# Out:
# Streaming output truncated to the last 5000 lines.
# VOCdevkit/VOC2012/SegmentationClass/2008_001874.png
# VOCdevkit/VOC2012/SegmentationClass/2008_001876.png
# VOCdevkit/VOC2012/SegmentationClass/2008_001882.png
# VOCdevkit/VOC2012/SegmentationClass/2008_001885.png
# VOCdevkit/VOC2012/SegmentationClass/2008_001895.png
# VOCdevkit/VOC2012/SegmentationClass/2008_001896.png
# VOCdevkit/VOC2012/SegmentationClass/2008_001926.png
# VOCdevkit/VOC2012/SegmentationClass/2008_001966.png
# VOCdevkit/VOC2012/SegmentationClass/2008_001971.png
# VOCdevkit/VOC2012/SegmentationClass/2008_001992.png
# VOCdevkit/VOC2012/SegmentationClass/2008_001997.png
# VOCdevkit/VOC2012/SegmentationClass/2008_002032.png
# VOCdevkit/VOC2012/SegmentationClass/2008_002043.png
# VOCdevkit/VOC2012/SegmentationClass/2008_002064.png
# VOCdevkit/VOC2012/SegmentationClass/2008_002066.png
# VOCdevkit/VOC2012/SegmentationClass/2008_002067.png
# VOCdevkit/VOC2012/SegmentationClass/2008_002073.png
# ...

# %%
# !wget http://host.robots.ox.ac.uk:8080/pascal/VOC/voc2007/VOCtest_06-Nov-2007.tar
# Out:
# --2021-04-01 14:29:59--  http://host.robots.ox.ac.uk:8080/pascal/VOC/voc2007/VOCtest_06-Nov-2007.tar
# Resolving host.robots.ox.ac.uk (host.robots.ox.ac.uk)... 129.67.94.152
# Connecting to host.robots.ox.ac.uk (host.robots.ox.ac.uk)|129.67.94.152|:8080... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 451020800 (430M) [application/x-tar]
# Saving to: ‘VOCtest_06-Nov-2007.tar’
#
# VOCtest_06-Nov-2007 100%[===================>] 430.13M  15.9MB/s    in 28s
#
# 2021-04-01 14:30:34 (15.2 MB/s) - ‘VOCtest_06-Nov-2007.tar’ saved [451020800/451020800]

# %%
# !tar -xvf /content/VOCtest_06-Nov-2007.tar -C /content/drive/MyDrive/data/VOC0712
# Out:
# Streaming output truncated to the last 5000 lines.
# VOCdevkit/VOC2007/JPEGImages/000725.jpg
# VOCdevkit/VOC2007/JPEGImages/000727.jpg
# VOCdevkit/VOC2007/JPEGImages/000732.jpg
# VOCdevkit/VOC2007/JPEGImages/000734.jpg
# VOCdevkit/VOC2007/JPEGImages/000735.jpg
# VOCdevkit/VOC2007/JPEGImages/000736.jpg
# VOCdevkit/VOC2007/JPEGImages/000737.jpg
# VOCdevkit/VOC2007/JPEGImages/000741.jpg
# VOCdevkit/VOC2007/JPEGImages/000743.jpg
# VOCdevkit/VOC2007/JPEGImages/000744.jpg
# VOCdevkit/VOC2007/JPEGImages/000745.jpg
# VOCdevkit/VOC2007/JPEGImages/000747.jpg
# VOCdevkit/VOC2007/JPEGImages/000749.jpg
# VOCdevkit/VOC2007/JPEGImages/000751.jpg
# VOCdevkit/VOC2007/JPEGImages/000757.jpg
# VOCdevkit/VOC2007/JPEGImages/000758.jpg
# VOCdevkit/VOC2007/JPEGImages/000759.jpg
# VOCdevkit/VOC2007/JPEGImages/000762.jpg
# VOCdevkit/VOC2007/JPEGImages/000765.jpg
# VOCdevkit/VOC2007/JPEGImages/000766.jpg
# VOCdevkit/VOC2007/JPEGImages/000769.jpg
# VOCdevkit/VOC2007/JPEGImages/000773.jpg
# ...

# %%
#!cd /content/pytorch-ssd && python train_ssd.py --dataset_type voc --datasets /content/drive/MyDrive/data/VOC0712/VOC2007 /content/drive/MyDrive/data/VOC0712/VOC2012 --validation_dataset /content/drive/MyDrive/data/VOC0712/test/VOCdevkit/VOC2007/ --net mb2-ssd-lite --base_net models/mb2-imagenet-71_8.pth  --scheduler cosine --lr 0.01 --t_max 200 --validation_epochs 5 --num_epochs 10 --use_cuda
# Out:
# 2021-04-01 13:25:07,464 - root - INFO - Use Cuda.
# 2021-04-01 13:25:07,465 - root - INFO - Namespace(balance_data=False, base_net='models/mb2-imagenet-71_8.pth', base_net_lr=None, batch_size=32, checkpoint_folder='models/', dataset_type='voc', datasets=['/content/drive/MyDrive/data/VOC0712/VOC2007', '/content/drive/MyDrive/data/VOC0712/VOC2012'], debug_steps=100, extra_layers_lr=None, freeze_base_net=False, freeze_net=False, gamma=0.1, lr=0.01, mb2_width_mult=1.0, milestones='80,100', momentum=0.9, net='mb2-ssd-lite', num_epochs=200, num_workers=4, pretrained_ssd=None, resume=None, scheduler='cosine', t_max=200.0, use_cuda=True, validation_dataset='/content/drive/MyDrive/data/VOC0712/test/VOCdevkit/VOC2007/', validation_epochs=5, weight_decay=0.0005)
# 2021-04-01 13:25:07,499 - root - INFO - Prepare training datasets.
# 2021-04-01 13:25:07,505 - root - INFO - No labels file, using default VOC classes.
# ...

# %%
# !cd /content/pytorch-ssd && python train_ssd.py --dataset_type voc --datasets /content/drive/MyDrive/data/VOC0712/VOC2007/ /content/drive/MyDrive/data/VOC0712/VOC2012/ --validation_dataset /content/drive/MyDrive/data/VOC0712/VOCdevkit/VOC2007/ --net mb2-ssd-lite --base_net models/mb2-imagenet-71_8.pth  --scheduler cosine --lr 0.01 --t_max 200 --validation_epochs 5 --num_epochs 10
# Out:
# 2021-04-01 14:57:43,125 - root - INFO - Use Cuda.
# 2021-04-01 14:57:43,125 - root - INFO - Namespace(balance_data=False, base_net='models/mb2-imagenet-71_8.pth', base_net_lr=None, batch_size=32, checkpoint_folder='models/', dataset_type='voc', datasets=['/content/drive/MyDrive/data/VOC0712/VOC2007/', '/content/drive/MyDrive/data/VOC0712/VOC2012/'], debug_steps=100, extra_layers_lr=None, freeze_base_net=False, freeze_net=False, gamma=0.1, lr=0.01, mb2_width_mult=1.0, milestones='80,100', momentum=0.9, net='mb2-ssd-lite', num_epochs=10, num_workers=4, pretrained_ssd=None, resume=None, scheduler='cosine', t_max=200.0, use_cuda=True, validation_dataset='/content/drive/MyDrive/data/VOC0712/VOCdevkit/VOC2007/', validation_epochs=5, weight_decay=0.0005)
# 2021-04-01 14:57:43,126 - root - INFO - Prepare training datasets.
# 2021-04-01 14:57:43,129 - root - INFO - No labels file, using default VOC classes.
# 2021-04-01 14:57:43,133 - root - INFO - No labels file, using default VOC classes.
# ...

# %%
# !cd /content/pytorch-ssd && python eval_ssd.py --net mb1-ssd  --dataset /content/drive/MyDrive/data/VOC0712/VOCdevkit/VOC2007/ --trained_model models/mobilenet-v1-ssd-mp-0_675.pth --label_file models/voc-model-labels.txt
# Out:
# Streaming output truncated to the last 5000 lines.
# Inference time:  0.0039327144622802734
# Prediction: 0.045501 seconds.
# process image 3704
# Load Image: 0.007157 seconds.
# Inference time:  0.00440526008605957
# Prediction: 0.024309 seconds.
# process image 3705
# Load Image: 0.005911 seconds.
# Inference time:  0.0044956207275390625
# Prediction: 0.036485 seconds.
# process image 3706
# Load Image: 0.006322 seconds.
# Inference time:  0.0044727325439453125
# Prediction: 0.020493 seconds.
# process image 3707
# Load Image: 0.005275 seconds.
# Inference time:  0.004268646240234375
# Prediction: 0.019638 seconds.
# process image 3708
# Load Image: 0.005785 seconds.
# Inference time:  0.004087924957275391
# Prediction: 0.011900 seconds.
# process image 3709
# Load Image: 0.006053 seconds.
# Inference time:  0.004193782806396484
# Prediction: 0.045088 seconds.
# process image 3710
# Load Image: 0.006086 seconds.
# Inference time:  0.0041086673736572266
# ...

# %%
# !unzip /content/videoCross_WalktoJPG.zip -d /content/drive/MyDrive/test_crosswalk
# Out:
# Archive:  /content/videoCross_WalktoJPG.zip
#   inflating: /content/drive/MyDrive/op/ezgif-frame-001.jpg
#   inflating: /content/drive/MyDrive/op/ezgif-frame-002.jpg
#   inflating: /content/drive/MyDrive/op/ezgif-frame-003.jpg
#   inflating: /content/drive/MyDrive/op/ezgif-frame-004.jpg
#   inflating: /content/drive/MyDrive/op/ezgif-frame-005.jpg
#   inflating: /content/drive/MyDrive/op/ezgif-frame-006.jpg
#   inflating: /content/drive/MyDrive/op/ezgif-frame-007.jpg
#   inflating: /content/drive/MyDrive/op/ezgif-frame-008.jpg
#   inflating: /content/drive/MyDrive/op/ezgif-frame-009.jpg
#   inflating: /content/drive/MyDrive/op/ezgif-frame-010.jpg
#   inflating: /content/drive/MyDrive/op/ezgif-frame-011.jpg
#   inflating: /content/drive/MyDrive/op/ezgif-frame-012.jpg
#   inflating: /content/drive/MyDrive/op/ezgif-frame-013.jpg
#   inflating: /content/drive/MyDrive/op/ezgif-frame-014.jpg
#   inflating: /content/drive/MyDrive/op/ezgif-frame-015.jpg
# ...

# %%
# !cd /content/pytorch-ssd && python train_ssd.py --dataset_type voc  --datasets /content/drive/MyDrive/data/VOC0712/VOC2007/ /content/drive/MyDrive/data/VOC0712/VOC2012/ --validation_dataset /content/drive/MyDrive/data/VOC0712/VOCdevkit/VOC2007/ --net mb2-ssd-lite --base_net models/mb2-imagenet-71_8.pth  --scheduler cosine --lr 0.01 --t_max 200 --validation_epochs 5 --num_epochs 200
# Out:
# 2021-04-01 16:44:51,677 - root - INFO - Use Cuda.
# 2021-04-01 16:44:51,677 - root - INFO - Namespace(balance_data=False, base_net='models/mb2-imagenet-71_8.pth', base_net_lr=None, batch_size=32, checkpoint_folder='models/', dataset_type='voc', datasets=['/content/drive/MyDrive/data/VOC0712/VOC2007/', '/content/drive/MyDrive/data/VOC0712/VOC2012/'], debug_steps=100, extra_layers_lr=None, freeze_base_net=False, freeze_net=False, gamma=0.1, lr=0.01, mb2_width_mult=1.0, milestones='80,100', momentum=0.9, net='mb2-ssd-lite', num_epochs=200, num_workers=4, pretrained_ssd=None, resume=None, scheduler='cosine', t_max=200.0, use_cuda=True, validation_dataset='/content/drive/MyDrive/data/VOC0712/VOCdevkit/VOC2007/', validation_epochs=5, weight_decay=0.0005)
# 2021-04-01 16:44:51,680 - root - INFO - Prepare training datasets.
# 2021-04-01 16:44:51,683 - root - INFO - No labels file, using default VOC classes.
# 2021-04-01 16:44:51,687 - root - INFO - No labels file, using default VOC classes.
# ...

# %%
# !cd /content/pytorch-ssd && python train_ssd.py --dataset_type voc  --datasets /content/drive/MyDrive/data/VOC0712/VOC2007/ /content/drive/MyDrive/data/VOC0712/VOC2012/ --validation_dataset /content/drive/MyDrive/data/VOC0712/VOCdevkit/VOC2007/ --net mb2-ssd-lite --base_net models/mb2-imagenet-71_8.pth  --scheduler cosine --lr 0.01 --t_max 200 --validation_epochs 5 --num_epochs 10
# Out:
# 2021-04-01 18:20:40,897 - root - INFO - Use Cuda.
# 2021-04-01 18:20:40,897 - root - INFO - Namespace(balance_data=False, base_net='models/mb2-imagenet-71_8.pth', base_net_lr=None, batch_size=32, checkpoint_folder='models/', dataset_type='voc', datasets=['/content/drive/MyDrive/data/VOC0712/VOC2007/', '/content/drive/MyDrive/data/VOC0712/VOC2012/'], debug_steps=100, extra_layers_lr=None, freeze_base_net=False, freeze_net=False, gamma=0.1, lr=0.01, mb2_width_mult=1.0, milestones='80,100', momentum=0.9, net='mb2-ssd-lite', num_epochs=10, num_workers=4, pretrained_ssd=None, resume=None, scheduler='cosine', t_max=200.0, use_cuda=True, validation_dataset='/content/drive/MyDrive/data/VOC0712/VOCdevkit/VOC2007/', validation_epochs=5, weight_decay=0.0005)
# 2021-04-01 18:20:40,898 - root - INFO - Prepare training datasets.
# 2021-04-01 18:20:40,901 - root - INFO - No labels file, using default VOC classes.
# 2021-04-01 18:20:40,906 - root - INFO - No labels file, using default VOC classes.
# ...
